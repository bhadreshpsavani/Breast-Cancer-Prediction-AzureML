# %% [markdown]
# <a href="https://colab.research.google.com/github/bhadreshpsavani/Breast-Cancer-Prediction-AzureML/blob/main/CreateFlowChart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Creating Flow Diagrams for Projects

# %%
from graphviz import Digraph

# %%
# Initiate a new Graph Object
graph = Digraph('Breast-Cancer-Prediction-Flowchart', format='png', )

# %%
# add nodes
graph.node('A', 'Add Breast Cancer Dataset in Workspace')
graph.node('B', 'Train Model Using Automated ML')
graph.node('C', 'Get Best Model from Automated ML Run')
graph.node('D', 'Perform Hyperparameter Tuning Using HyperDrive')
graph.node('E', 'Get Best Model from HyperDrive Run')
graph.node('F', 'Compare Both Model and Deploy the best one')
graph.node('G', 'Perform Inference Request on Deployed Endpoint')

# %%
graph.edges(['AB', 'AD', 'BC', 'DE', 'EF', 'CF', 'FG'])

# %%
graph

# %%
# if want to save the graph
# graph.render('breast_cancer_prediction_flow_graph', view=True)

# %%
graph.node_attr.update({'shape': 'plaintext'})
graph

# %%
graph.node_attr.update({'shape': 'egg'})
graph

# %%
graph.edge_attr.update(arrowhead='vee', arrowsize='2')
graph

# %% [markdown]
# Complete User Manual Can be found on the Official [documentation](https://graphviz.readthedocs.io/en/stable/manual.html#jupyter-notebooks) of graphviz
